# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_fertility_rate_1950_2019 = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8#%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C", match="Коефіцієнт народжуваності в регіонах України")

# %%
df = raw_fertility_rate_1950_2019[0]

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
df.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі

# %%
df.shape
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126    —    —
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82    —
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51    —
# 12          Львівська  234.0  240.0  171.0   140    91   119  119   87
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112   71
# 14            Одеська  241.0  192.0  148.0   126    80   127  123   88
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100   65
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148  107
# 17            Сумська  216.0  184.0  132.0   115    70    97   92   60
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109   76
# 19         Харківська  197.0  173.0  140.0   114    68    99  101   68
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115   81
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112   79
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98   64
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129   92
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90   61
# 25               Київ    NaN  174.0  159.0   120    73   120  121  110
# 26        Севастополь    NaN    NaN    NaN   125    70   120    —    —
# 27            Україна  228.0  205.0  152.0   126    78   114  111   81

# %% [markdown]
# Замініть у таблиці значення "—" на значення NaN

# %%
df = df.replace("—", np.nan)
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82   71
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123   103   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51   68
# 12          Львівська  234.0  240.0  171.0   140    91   119  119   87
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112   71
# 14            Одеська  241.0  192.0  148.0   126    80   127  123   88
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100   65
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148  107
# 17            Сумська  216.0  184.0  132.0   115    70    97   92   60
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109   76
# 19         Харківська  197.0  173.0  140.0   114    68    99  101   68
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115   81
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112   79
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98   64
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129   92
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90   61
# 25               Київ    NaN  174.0  159.0   120    69   120  121  110
# 26        Севастополь    NaN    NaN    NaN   125    70   120  121  110
# 27            Україна  228.0  205.0  152.0   126    78   114  111   81

# %% [markdown]
# Визначте типи всіх стовпців за допомогою

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Регіон  28 non-null     object
#  1   1950    26 non-null     float64
#  2   1960    27 non-null     float64
#  3   1970    27 non-null     float64
#  4   1990    28 non-null     int64
#  5   2000    28 non-null     int64
#  6   2012    28 non-null     int64
#  7   2014    27 non-null     object
#  8   2019    27 non-null     object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 2.1+ KB

# %% [markdown]
# Замініть типи нечислових колонок на числові

# %%
df['2014'] = pd.to_numeric(df['2014'])
df['2019'] = pd.to_numeric(df['2019'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Регіон  28 non-null     object
#  1   1950    26 non-null     float64
#  2   1960    27 non-null     float64
#  3   1970    27 non-null     float64
#  4   1990    28 non-null     int64
#  5   2000    28 non-null     int64
#  6   2012    28 non-null     int64
#  7   2014    27 non-null     float64
#  8   2019    27 non-null     float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці

# %%
df.isnull().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      1
# 2019      1
# dtype: int64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
df = df.drop(27, axis=0)
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0   71.0
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123   103   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# 11          Луганська  262.0  235.0  144.0   116    62    96   51.0   68.0
# 12          Львівська  234.0  240.0  171.0   140    91   119  119.0   87.0
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112.0   71.0
# 14            Одеська  241.0  192.0  148.0   126    80   127  123.0   88.0
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100.0   65.0
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148.0  107.0
# 17            Сумська  216.0  184.0  132.0   115    70    97   92.0   60.0
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109.0   76.0
# 19         Харківська  197.0  173.0  140.0   114    68    99  101.0   68.0
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115.0   81.0
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112.0   79.0
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98.0   64.0
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129.0   92.0
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90.0   61.0
# 25               Київ    NaN  174.0  159.0   120    69   120  121.0  110.0
# 26        Севастополь    NaN    NaN    NaN   125    70   120  121.0  110.0

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців

# %%
df["1950"].fillna(df["1950"].mean(), inplace=True)
df["1960"].fillna(df["1960"].mean(), inplace=True)
df["1970"].fillna(df["1970"].mean(), inplace=True)
df["2014"].fillna(df["2014"].mean(), inplace=True)
df["2019"].fillna(df["2019"].mean(), inplace=True)
df.isnull().sum()
# Out:
# Регіон    0
# 1950      0
# 1960      0
# 1970      0
# 1990      0
# 2000      0
# 2012      0
# 2014      0
# 2019      0
# dtype: int64

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
df[df["2019"] > df["2019"].mean()]
# Out:
#                Регіон    1950        1960   1970  1990  2000  2012   2014  \
# 2           Волинська  247.00  250.000000  179.0   153   112   148  141.0
# 6        Закарпатська  314.00  273.000000  207.0   168   115   151  146.0
# 8   Івано-Франківська  243.00  248.000000  182.0   155   103   124  122.0
# 12          Львівська  234.00  240.000000  171.0   140    91   119  119.0
# 14            Одеська  241.00  192.000000  148.0   126    80   127  123.0
# 16         Рівненська  269.00  267.000000  193.0   158   118   159  148.0
# 20         Херсонська  208.00  214.000000  166.0   143    85   117  115.0
# 23        Чернівецька  247.00  218.000000  170.0   148   101   128  129.0
# 25               Київ  231.04  174.000000  159.0   120    69   120  121.0
# 26        Севастополь  231.04  207.576923  156.0   125    70   120  121.0
#
#      2019
# 2   101.0
# 6   104.0
# 8    88.0
# 12   87.0
# 14   88.0
# 16  107.0
# 20   81.0
# 23   92.0
# 25  110.0
# 26  110.0

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2014 році?

# %%
df[df["2014"] == df["2014"].max()]
# Out:
#         Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 16  Рівненська  269.0  267.0  193.0   158   118   159  148.0  107.0

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
ax = df.plot.bar(x="Регіон", y="2019", legend=False, color="grey")
plt.title("Показник народжуваності по регіонам України за 2019 рік")
plt.xlabel("Регіони України", fontsize="large")
plt.ylabel("Народжуваність, тис.", fontsize="large")
plt.rcParams["figure.figsize"] = [12, 8]
ax.grid()
plt.show()
